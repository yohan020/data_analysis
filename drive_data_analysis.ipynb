# %% [markdown]
# <a href="https://colab.research.google.com/github/yohan020/data_analysis/blob/main/drive_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('/train/A.csv', engine='python', on_bad_lines='skip')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8804 entries, 0 to 8803
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Test_id     8804 non-null   object
#  1   Test        8804 non-null   object
#  2   PrimaryKey  8804 non-null   object
#  3   Age         8804 non-null   object
#  4   TestDate    8804 non-null   int64
#  5   A1-1        8804 non-null   object
#  6   A1-2        8804 non-null   object
#  7   A1-3        8804 non-null   object
#  8   A1-4        8804 non-null   object
#  9   A2-1        8804 non-null   object
#  10  A2-2        8804 non-null   object
#  11  A2-3        8804 non-null   object
#  12  A2-4        8804 non-null   object
#  13  A3-1        8804 non-null   object
#  14  A3-2        8804 non-null   object
#  15  A3-3        8804 non-null   object
#  16  A3-4        8804 non-null   object
#  17  A3-5        8804 non-null   object
#  18  A3-6        8804 non-null   object
# ...

# %%
df_train[9:13].head()
# Out:
#                                               Test_id Test  \
# 9   0x21E252D2D55222737D1394671AAFACD327D50B99AA1D...    A
# 10  0x669A2301ED2CE93C7DA40AF85844E3A272223FF8340E...    A
# 11  0x0055A75E64D13B26B242FDF11448842FC943AC9AE700...    A
# 12  0xB042BC3F0539149A159E252A7C92051172EC6889AB9A...    A
#
#                                            PrimaryKey  Age  TestDate  \
# 9   0x21E252D2D55222737D1394671AAFACD327D50B99AA1D...  20a    201803
# 10  0x669A2301ED2CE93C7DA40AF85844E3A272223FF8340E...  20a    201807
# 11  0x0055A75E64D13B26B242FDF11448842FC943AC9AE700...  20a    201805
# 12  0xB042BC3F0539149A159E252A7C92051172EC6889AB9A...  20a    201807
#
#                                    A1-1                                 A1-2  \
# 9   2,1,1,2,2,2,1,1,1,2,2,1,1,1,1,2,2,2  2,3,1,2,2,3,2,2,2,1,1,3,3,1,1,1,3,3
# 10  2,2,2,2,1,1,1,1,1,2,1,2,2,1,1,1,2,2  2,3,2,1,3,1,1,3,2,3,2,3,2,2,3,1,1,1
# 11  1,2,1,1,1,1,2,2,1,2,2,1,2,2,1,1,2,2  1,2,2,3,1,2,1,3,1,1,3,3,2,1,3,2,3,2
# ...
